# %%
import hashlib
import logging
import re
import requests
from bs4 import BeautifulSoup
import pickle
import pandas as pd

# %%
log = logging.getLogger(__name__)

# %%
def get_content(url):
    """Get url contents from web or local cache.
    
    This function impliments a simple cache using the Python Pickle library. 
    When called, the function computes the SHA1 sum of the URL. If a file 
    with that name exists, then the file is loaded and it's contents are 
    returned. If the file does not exist, a GET request is made and the 
    result is saved to disk for future use.
    """
    log.info('Getting contents for URL %s', url)
    file_name = ''.join([hashlib.sha1(url.encode('utf-8')).hexdigest(), '.pickle'])
    try:
        with open(file_name, 'rb') as file:
            log.info('Cache file opened, loading pickle.')
            r = pickle.load(file)
    except FileNotFoundError as e:
        log.info('Got FileNotFoundError, making GET request.')
        r = requests.get(url)
        with open(file_name, 'wb') as file:
            pickle.dump(r, file)
    return r.content

# %%
# 4s softcase under 700g
URL = r"https://hobbyking.com/en_us/batteries-chargers/batteries/lipo.html?config=54&battery_pack_type=2836&unit_weight_filterable=0-700&wrh=2%2C3"

# %%
soup = BeautifulSoup(get_content(URL))
product_cards = soup.find_all(class_='product-card')
products = []
for product in product_cards:
    p = {}
    p['Name'] = product.find('a', class_='link -name').get_text()
    p['URL'] = product.find('a', class_='link -name')['href']
    sub_soup = BeautifulSoup(get_content(p['URL']))
    try:
        p['Price'] = sub_soup.find(class_='price-box').find(class_='regular-price').find(class_='price').get_text()
    except AttributeError as _:
        p['Price'] = sub_soup.find(class_='price-box').find(class_='old-price').find(class_='price').get_text()
    specs_found = False
    for paragraph in sub_soup.find(id='tab-description').div.find_all():
        text = paragraph.get_text("\n")
        spec_names = ['Specs:', 'Spec.', 'Spec:']
        if ('Specs:' in text) or ('Spec.' in text) or ('Spec:' in text):
            specs_found = True
            for br in paragraph.find_all("br"):
                br.replace_with("\n")
            text = paragraph.get_text()
            text = text.split('\n')
            for line in text:
                split = line.split(':')
                if len(split) == 2 and split[0] and split[1]:
                    p[split[0]] = split[1]
                    
    for key in p.keys():
        if 'weight' in key.lower():
            p['Weight'] = p.pop(key)
        elif 'capacity' in key.lower():
            p['Capacity'] = p.pop(key)
        elif 'discharge plug' in key.lower():
            p['Discharge Plug'] = p.pop(key)
        elif 'charge plug' in key.lower():
            p['Balance Plug'] = p.pop(key)
        elif 'Constant Discharge' in key:
            p['Constant Discharge'] = p.pop(key)
        elif 'Peak Discharge' in key:
            p['Peak Discharge'] = p.pop(key)
        elif 'Pack Size' in key:
            p['Dimensions'] = p.pop(key)
        elif 'battery size' in key.lower():
            p['Dimensions'] = p.pop(key)
        elif 'dimension' in key.lower():
            p['Dimensions'] = p.pop(key)
        elif 'configuration' in key.lower():
            p['Configuration'] = p.pop(key)
    
    
    # Account for inconsistency on HK website
    if p['URL'] == r'https://hobbyking.com/en_us/turnigy-2200mah-4s-20c-lipoly-pack-w-xt60-connector.html':
        p['Discharge'] = p['Constant Discharge']
    
    # Split Discharge into Peak and Continuous
    if 'Discharge' in p.keys():
        discharge = re.findall(r'([0-9].C)', p.pop('Discharge'))
        if discharge:
            p['Constant Discharge'] = discharge[0]
            p['Peak Discharge'] = discharge[1]
    
    # Strip non-numeric characters from numeric fields
    no_number_re = r'[^0-9|.]'
    p['Capacity [mAh]'] = float(re.sub(no_number_re, '', p.pop('Capacity')))
    p['Weight [g]'] = float(re.sub(no_number_re, '', p.pop('Weight')))
    p['Price [USD]'] = float(re.sub(no_number_re, '', p.pop('Price')))
    p['Constant Discharge [c]'] = int(re.sub(no_number_re, '', p.pop('Constant Discharge')))
    p['Peak Discharge [c]'] = int(re.sub(no_number_re, '', p.pop('Peak Discharge')))
    
    # Fix error on HK Website
    if p['URL'] == r'https://hobbyking.com/en_us/turnigy-graphene-850mah-4s-75c-lipo-pack-w-xt60u.html':
        p['Capacity'] = float(850)
    
    print(p)
    products.append(p)
    if not specs_found: raise Exception('No Specs')
# Out:
# {'Name': 'Turnigy Graphene 1300mAh 4S 65C Lipo Pack w/XT60                                ', 'URL': 'https://hobbyking.com/en_us/graphene-1300mah-4s-65c-w-xt60.html', 'Voltage': '\xa04S1P / 4 Cell / 14.8V', 'Balance Plug': '\xa0JST-XH', 'Dimensions': '\xa075x36x36mm', 'Discharge Plug': '\xa0XT-60', 'Capacity [mAh]': 1300.0, 'Weight [g]': 176.0, 'Price [USD]': 26.93, 'Constant Discharge [c]': 65, 'Peak Discharge [c]': 30}
# {'Name': 'Turnigy Graphene Panther 850mAh 4S 75C Battery Pack w/XT60                                ', 'URL': 'https://hobbyking.com/en_us/turnigy-graphene-850mah-4s-75c-lipo-pack-w-xt60u.html', 'Cell Count': ' 4', 'Voltage': ' 14.8V', 'Pack Resistance': ' 22mΩ', 'Dimensions': ' 56x31x38mm', 'Balance Plug': ' JST-XH', 'Discharge Plug': ' XT60', 'Capacity [mAh]': 8500.0, 'Weight [g]': 120.0, 'Price [USD]': 18.78, 'Constant Discharge [c]': 75, 'Peak Discharge [c]': 150, 'Capacity': 850.0}
# {'Name': 'Turnigy Graphene Panther 500mAh 4S 75C Battery Pack w/XT30                                ', 'URL': 'https://hobbyking.com/en_us/turnigy-graphene-500mah-4s-75c-lipo-pack-w-xt30.html', 'Cell Count': ' 4', 'Voltage': ' 14.8V', 'Pack Resistance': ' 30mΩ', 'Dimensions': ' 56x31x25mm', 'Balance Plug': ' JST-XH', 'Discharge Plug': ' XT30', 'Capacity [mAh]': 500.0, 'Weight [g]': 76.0, 'Price [USD]': 21.67, 'Constant Discharge [c]': 75, 'Peak Discharge [c]': 150}
# {'Name': 'Turnigy 1400mAh 4S 65C Lipo Pack w/XT60                                ', 'URL': 'https://hobbyking.com/en_us/turnigy-1400mah-4s-65c-lipo-pack-w-xt60.html', 'Dimensions': '\xa091.5 x\xa035 x31mm', 'Balance Plug': ' JST-XH', 'Discharge Plug': ' XT60', 'Configuration': ' 4S1P / 14.8v / 4Cell', 'Capacity [mAh]': 1400.0, 'Weight [g]': 179.0, 'Price [USD]': 14.99, 'Constant Discharge [c]': 65, 'Peak Discharge [c]': 130}
# {'Name': 'Turnigy 1400mAh 4S 40C Lipo Pack w/XT60                                ', 'URL': 'https://hobbyking.com/en_us/turnigy-1400mah-4s-40c-lipo-pack-w-xt60.html', 'Dimensions': '\xa087.5 x\xa033.5 x 27mm', 'Balance Plug': ' JST-XH', 'Discharge Plug': ' XT60', 'Configuration': ' 4S1P / 14.8v / 4Cell', 'Capacity [mAh]': 1400.0, 'Weight [g]': 153.0, 'Price [USD]': 13.99, 'Constant Discharge [c]': 40, 'Peak Discharge [c]': 80}
# {'Name': 'Turnigy Graphene Panther 4000mAh 4S 75C Battery Pack w/XT90                                ', 'URL': 'https://hobbyking.com/en_us/turnigy-graphene-4000mah-4s-75c-lipo-pack-w-xt90.html', 'Cell Count': ' 4', 'Voltage': ' 14.8V', 'Pack Resistance': ' 12mΩ', 'Dimensions': ' 145x51x36mm', 'Balance Plug': ' JST-XH', 'Discharge Plug': ' XT90', 'Capacity [mAh]': 4000.0, 'Weight [g]': 526.0, 'Price [USD]': 70.83, 'Constant Discharge [c]': 75, 'Peak Discharge [c]': 150}
# {'Name': 'Turnigy Nano-Tech Plus 650mAh 4S 70C Lipo Pack w/XT30 (Removable Balance Plug)                                ', 'URL': 'https://hobbyking.com/en_us/turnigy-nano-tech-650mah-4s-70c-lipo-pack-hr-tech.html', 'Voltage': '\xa04S1P /\xa04 Cell / 14.8V', 'Balance Plug': '\xa0JST-XH', 'Dimensions': '\xa080.5x26x23.1mm', 'Discharge Plug': '\xa0XT30', 'Capacity [mAh]': 650.0, 'Weight [g]': 84.0, 'Price [USD]': 13.09, 'Constant Discharge [c]': 70, 'Peak Discharge [c]': 40}
# {'Name': 'Turnigy Nano-Tech Plus 1000mAh 4S 70C Lipo Pack w/XT60                                ', 'URL': 'https://hobbyking.com/en_us/turnigy-nano-tech-1000mah-4s-70c-lipo-pack-xt60-hr-tech.html', 'Voltage': '\xa04S1P /\xa04 Cell / 14.8V', 'Balance Plug': '\xa0JST-XH', 'Dimensions': '\xa072.5x35x26mm', 'Discharge Plug': '\xa0XT60', 'Capacity [mAh]': 1000.0, 'Weight [g]': 124.88, 'Price [USD]': 16.95, 'Constant Discharge [c]': 70, 'Peak Discharge [c]': 40}
# {'Name': 'Turnigy Nano-Tech Plus 1300mAh 4S 70C Lipo Pack w/XT60                                ', 'URL': 'https://hobbyking.com/en_us/turnigy-nano-tech-1300mah-4s-70c-lipo-pack-xt60-hr-tech.html', 'Voltage': '\xa04S1P /\xa04 Cell / 14.8V', 'Balance Plug': '\xa0JST-XH', 'Dimensions': '\xa073.5x35x32.8mm', 'Discharge Plug': '\xa0XT60', 'Capacity [mAh]': 1300.0, 'Weight [g]': 154.76, 'Price [USD]': 18.99, 'Constant Discharge [c]': 70, 'Peak Discharge [c]': 40}
# {'Name': 'Turnigy Nano-Tech Plus 1600mAh 4S 70C Lipo Pack w/XT60                                ', 'URL': 'https://hobbyking.com/en_us/turnigy-nano-tech-1600mah-4s-70c-lipo-pack-xt60-hr-tech.html', 'Voltage': '\xa04S1P /\xa04 Cell / 14.8V', 'Balance Plug': '\xa0JST-XH', 'Dimensions': '\xa073.5x35x39.2mm', 'Discharge Plug': '\xa0XT60', 'Capacity [mAh]': 1600.0, 'Weight [g]': 182.65, 'Price [USD]': 26.99, 'Constant Discharge [c]': 70, 'Peak Discharge [c]': 40}
# {'Name': 'Turnigy Nano-Tech Plus + 3300mAh 4S 70C Lipo Pack w/XT90                                ', 'URL': 'https://hobbyking.com/en_us/turnigy-nano-tech-3300mah-4s-70c-lipo-pack-w-xt-90-hr-tech.html', 'Voltage': '\xa04S1P /\xa04 Cell / 14.8V', 'Balance Plug': '\xa0JST-XH', 'Dimensions': '\xa0135x44x31.6mm', 'Discharge Plug': '\xa0XT90', 'Capacity [mAh]': 3300.0, 'Weight [g]': 393.19, 'Price [USD]': 49.48, 'Constant Discharge [c]': 70, 'Peak Discharge [c]': 40}
# {'Name': 'Turnigy Nano-Tech 2650mAh 4S 30C Lipo Pack w/XT60                                ', 'URL': 'https://hobbyking.com/en_us/turnigy-nano-tech-2650mah-4s-30c-lipo-pack-wxt60.html', 'Voltage': '\xa04S1P /\xa04 Cell / 14.8V', 'Balance Plug': '\xa0JST-XH', 'Dimensions': '\xa0135x44x21.4mm', 'Discharge Plug': '\xa0XT60', 'Capacity [mAh]': 2650.0, 'Weight [g]': 266.35, 'Price [USD]': 27.15, 'Constant Discharge [c]': 30, 'Peak Discharge [c]': 60}
# {'Name': 'Turnigy Graphene Panther 1000mAh 4S 75C Battery Pack                                ', 'URL': 'https://hobbyking.com/en_us/graphene-1000mah-4s-75c.html', 'Cell Count': ' 4', 'Voltage': ' 14.8V', 'Pack Resistance': ' 17mΩ', 'Dimensions': ' 75x35x30mm', 'Balance Plug': ' JST-XH-5P', 'Discharge Plug': ' XT60', 'Capacity [mAh]': 1000.0, 'Weight [g]': 148.0, 'Price [USD]': 23.78, 'Constant Discharge [c]': 75, 'Peak Discharge [c]': 150}
# {'Name': 'Turnigy Graphene Panther 1300mAh 4S 75C Battery Pack (Removable Balance Lead)                                ', 'URL': 'https://hobbyking.com/en_us/graphene-1300mah-4s-75c-removable-balance-lead.html', 'Cell Count': ' 4', 'Voltage': ' 14.8V', 'Pack Resistance': ' 16mΩ', 'Dimensions': ' 78x35x36mm', 'Balance Plug': ' JST-XH-5P', 'Discharge Plug': ' XT60', 'Capacity [mAh]': 1300.0, 'Weight [g]': 175.0, 'Price [USD]': 26.89, 'Constant Discharge [c]': 75, 'Peak Discharge [c]': 150}
# {'Name': 'Turnigy Graphene Panther 1600mAh 4S 75C Battery Pack                                ', 'URL': 'https://hobbyking.com/en_us/graphene-1600mah-4s-75c-normal-pack.html', 'Cell Count': ' 4', 'Voltage': ' 14.8V', 'Pack Resistance': ' 14mΩ', 'Dimensions': ' 91x35x30mm', 'Balance Plug': ' JST-XH-5P', 'Discharge Plug': ' XT60', 'Capacity [mAh]': 1600.0, 'Weight [g]': 212.0, 'Price [USD]': 34.98, 'Constant Discharge [c]': 75, 'Peak Discharge [c]': 150}
# {'Name': 'Turnigy Graphene Panther 1600mAh 4S 75C Square Pack                                ', 'URL': 'https://hobbyking.com/en_us/graphene-1600mah-4s-75c-square-pack.html', 'Cell Count': ' 4', 'Voltage': ' 14.8V', 'Pack Resistance': ' 14mΩ', 'Dimensions': ' 67x49x36mm', 'Balance Plug': ' JST-XH-5P', 'Discharge Plug': ' XT60', 'Capacity [mAh]': 1600.0, 'Weight [g]': 212.0, 'Price [USD]': 36.81, 'Constant Discharge [c]': 75, 'Peak Discharge [c]': 150}
# {'Name': 'Turnigy Graphene Panther 650mAh 4S 75C Battery Pack                                ', 'URL': 'https://hobbyking.com/en_us/graphene-650mah-4s-75c.html', 'Cell Count': ' 4', 'Voltage': ' 14.8V', 'Pack Resistance': ' 40mΩ', 'Dimensions': ' 56x31x29mm', 'Balance Plug': ' JST-XH-5P', 'Discharge Plug': ' XT30', 'Capacity [mAh]': 650.0, 'Weight [g]': 94.0, 'Price [USD]': 13.4, 'Constant Discharge [c]': 75, 'Peak Discharge [c]': 150}
# {'Name': 'Turnigy Graphene Panther 2200mAh 4S 75C Battery Pack                                ', 'URL': 'https://hobbyking.com/en_us/graphene-2200mah-4s-75c.html', 'Cell Count': ' 4', 'Voltage': ' 14.8V', 'Pack Resistance': ' 13mΩ', 'Dimensions': ' 106x35x41mm', 'Balance Plug': ' JST-XH-5P', 'Discharge Plug': ' XT60', 'Capacity [mAh]': 2200.0, 'Weight [g]': 295.0, 'Price [USD]': 42.34, 'Constant Discharge [c]': 75, 'Peak Discharge [c]': 150}
# {'Name': 'Turnigy 1800mAh 4S 40C Lipo Pack                                ', 'URL': 'https://hobbyking.com/en_us/turnigy-1800mah-4s-40c-lipo-pack.html', 'Dimensions': ' 110 x 34 x 27mm', 'Balance Plug': ' JST-XH ', 'Discharge Plug': ' XT60\xa0 \xa0', 'Configuration': ' 4S1P / 14.8v / 4Cell', 'Capacity [mAh]': 1800.0, 'Weight [g]': 213.0, 'Price [USD]': 23.67, 'Constant Discharge [c]': 40, 'Peak Discharge [c]': 50}
# {'Name': 'Turnigy 2200mAh 4S 30C Lipo Pack                                ', 'URL': 'https://hobbyking.com/en_us/turnigy-2200mah-4s-30c-lipo-pack.html', 'Dimensions': '\xa0105 x\xa034 x 35mm', 'Balance Plug': ' JST-XH', 'Discharge Plug': ' XT60\xa0', 'Configuration': ' 4S1P / 14.8v / 4Cell', 'Capacity [mAh]': 2200.0, 'Weight [g]': 258.0, 'Price [USD]': 23.36, 'Constant Discharge [c]': 30, 'Peak Discharge [c]': 40}
# {'Name': 'Turnigy 2200mAh 4S 40C Lipo Pack                                ', 'URL': 'https://hobbyking.com/en_us/turnigy-2200mah-4s-40c-lipo-pack.html', 'Dimensions': ' 105 x 34 x 34mm', 'Balance Plug': ' JST-XH ', 'Discharge Plug': ' XT60', 'Configuration': ' 4S1P / 14.8v / 4Cell', 'Capacity [mAh]': 2200.0, 'Weight [g]': 248.0, 'Price [USD]': 24.94, 'Constant Discharge [c]': 40, 'Peak Discharge [c]': 50}
# {'Name': 'ZIPPY Flightmax 1800mAh 4S1P 40C                                ', 'URL': 'https://hobbyking.com/en_us/zippy-flightmax-1800mah-4s1p-40c.html', 'Voltage': ' 4S1P /\xa04 Cell / 14.8V', 'Balance Plug': ' JST-XH', 'Dimensions': ' 105x35x28mm', 'Discharge Plug': ' XT60', 'Capacity [mAh]': 1800.0, 'Weight [g]': 222.0, 'Price [USD]': 19.15, 'Constant Discharge [c]': 40, 'Peak Discharge [c]': 50}
# {'Name': 'ZIPPY Flightmax 2200mAh 4S1P 30C                                ', 'URL': 'https://hobbyking.com/en_us/zippy-flightmax-2200mah-4s1p-30c.html', 'Voltage': ' 4S1P /\xa04 Cell / 14.8v', 'Balance Plug': ' JST-XH', 'Dimensions': ' 103x35x34mm', 'Discharge Plug': ' XT60', 'Capacity [mAh]': 2200.0, 'Weight [g]': 233.0, 'Price [USD]': 21.06, 'Constant Discharge [c]': 30, 'Peak Discharge [c]': 40}
# {'Name': 'ZIPPY Flightmax 2200mAh 4S1P 40C                                ', 'URL': 'https://hobbyking.com/en_us/zippy-flightmax-2200mah-4s1p-40c.html', 'Voltage': ' 4S1P /\xa04 Cell / 14.8V', 'Balance Plug': ' JST-XH', 'Dimensions': ' 105x34x36mm', 'Discharge Plug': ' XT60', 'Capacity [mAh]': 2200.0, 'Weight [g]': 241.0, 'Price [USD]': 22.47, 'Constant Discharge [c]': 40, 'Peak Discharge [c]': 50}
# {'Name': 'ZIPPY Flightmax 2650mAh 4S1P 45C                                ', 'URL': 'https://hobbyking.com/en_us/zippy-flightmax-2650mah-4s1p-45c.html', 'Voltage': ' 4S1P /\xa04 Cell / 14.8V', 'Balance Plug': ' JST-XH', 'Dimensions': ' 137x45x25mm', 'Discharge Plug': ' 5.5mm Bullet Connector', 'Capacity [mAh]': 2650.0, 'Weight [g]': 329.0, 'Price [USD]': 28.64, 'Constant Discharge [c]': 45, 'Peak Discharge [c]': 55}
# {'Name': 'ZIPPY Flightmax 2800mAh 4S1P 30C                                ', 'URL': 'https://hobbyking.com/en_us/zippy-flightmax-2800mah-4s1p-30c.html', 'Voltage': ' 4S1P /\xa04 Cell / 14.8V', 'Balance Plug': ' JST-XH', 'Dimensions': ' 109x35x38mm', 'Discharge Plug': ' XT60', 'Capacity [mAh]': 2800.0, 'Weight [g]': 288.0, 'Price [USD]': 28.27, 'Constant Discharge [c]': 30, 'Peak Discharge [c]': 40}
# {'Name': 'ZIPPY Flightmax 4000mAh 4S1P 20C                                ', 'URL': 'https://hobbyking.com/en_us/zippy-flightmax-4000mah-4s1p-20c.html', 'Voltage': '\xa04S1P /\xa04 Cell / 14.8v', 'Balance Plug': '\xa0JST-XH', 'Dimensions': '\xa0143x53x27mm', 'Discharge Plug': '\xa04mm Bullet-Connector', 'Capacity [mAh]': 4000.0, 'Weight [g]': 399.0, 'Price [USD]': 30.41, 'Constant Discharge [c]': 20, 'Peak Discharge [c]': 30}
# {'Name': 'ZIPPY Flightmax 4200mAh 4S1P 30C LiFePo4 Pack                                ', 'URL': 'https://hobbyking.com/en_us/zippy-flightmax-4200mah-4s1p-30c-lifepo4-pack.html', 'Voltage': ' 4S1P / 13.2v', 'Max Charge Rate': ' 2C', 'Balance Plug': ' JST-XH', 'Discharge Plug': ' 5.5mm Bullet-Connector', 'Dimensions': ' 145mm x 52mm x 36mm', 'Capacity [mAh]': 4200.0, 'Weight [g]': 512.0, 'Price [USD]': 48.98, 'Constant Discharge [c]': 30, 'Peak Discharge [c]': 40}
# {'Name': 'ZIPPY Flightmax 4500mAh 4S1P 45C                                ', 'URL': 'https://hobbyking.com/en_us/zippy-flightmax-4500mah-4s1p-45c.html', 'Voltage': ' 4S1P /\xa04 Cell / 14.8V', 'Balance Plug': ' JST-XH', 'Dimensions': ' 146x52x34mm', 'Discharge Plug': ' 5.5mm Bullet Connector', 'Capacity [mAh]': 4500.0, 'Weight [g]': 527.0, 'Price [USD]': 50.38, 'Constant Discharge [c]': 45, 'Peak Discharge [c]': 55}
# {'Name': 'ZIPPY Compact 1300mAh 4S 25C Lipo Pack                                ', 'URL': 'https://hobbyking.com/en_us/zippy-compact-1300mah-4s-25c-lipo-pack.html', 'Voltage': ' 4S1P / 4 Cell / 14.8V', 'Balance Plug': ' JST-XH', 'Dimensions': ' 73x35x31mm', 'Discharge Plug': ' XT60', 'Capacity [mAh]': 1300.0, 'Weight [g]': 142.0, 'Price [USD]': 13.83, 'Constant Discharge [c]': 25, 'Peak Discharge [c]': 35}
# {'Name': 'ZIPPY Compact 1600mAh 4S 35C Lipo Pack                                ', 'URL': 'https://hobbyking.com/en_us/zippy-compact-1600mah-4s-35c-lipo-pack.html', 'Voltage': ' 4S1P /\xa04 Cell / 14.8V', 'Balance Plug': ' JST-XH', 'Dimensions': ' 106x34x23mm', 'Discharge Plug': ' XT60', 'Capacity [mAh]': 1600.0, 'Weight [g]': 178.0, 'Price [USD]': 19.39, 'Constant Discharge [c]': 35, 'Peak Discharge [c]': 45}
# {'Name': 'ZIPPY Compact 2200mAh 4S 25C Lipo Pack                                ', 'URL': 'https://hobbyking.com/en_us/zippy-compact-2200mah-4s-25c-lipo-pack.html', 'Voltage': ' 4S1P /\xa04 Cell / 14.8V', 'Balance Plug': ' JST-XH', 'Dimensions': ' 107x28x34mm', 'Discharge Plug': ' XT60', 'Capacity [mAh]': 2200.0, 'Weight [g]': 210.0, 'Price [USD]': 17.82, 'Constant Discharge [c]': 25, 'Peak Discharge [c]': 35}
# {'Name': 'ZIPPY Compact 2700mAh 4S 25C Lipo Pack                                ', 'URL': 'https://hobbyking.com/en_us/zippy-compact-2700mah-4s-25c-lipo-pack.html', 'Voltage': ' 4S1P /\xa04 Cell / 14.8V', 'Balance Plug': ' JST-XH', 'Dimensions': ' 137x44x23mm', 'Discharge Plug': ' HXT4mm', 'Capacity [mAh]': 2700.0, 'Weight [g]': 278.0, 'Price [USD]': 21.1, 'Constant Discharge [c]': 25, 'Peak Discharge [c]': 35}
# {'Name': 'ZIPPY Compact 3700mAh 4S 25C Lipo Pack                                ', 'URL': 'https://hobbyking.com/en_us/zippy-compact-3700mah-4s-25c-lipo-pack.html', 'Voltage': ' 4S1P /\xa04 Cell / 14.8V', 'Balance Plug': ' JST-XH', 'Dimensions': ' 146x27x44mm', 'Discharge Plug': ' HXT4mm', 'Capacity [mAh]': 3700.0, 'Weight [g]': 343.0, 'Price [USD]': 30.57, 'Constant Discharge [c]': 25, 'Peak Discharge [c]': 35}
# {'Name': 'ZIPPY Compact 5000mAh 4S 25C Lipo Pack                                ', 'URL': 'https://hobbyking.com/en_us/zippy-compact-5000mah-4s-25c-lipo-pack.html', 'Voltage': ' 4S1P /\xa04 Cell / 14.8V', 'Balance Plug': ' JST-XH', 'Dimensions': ' 162x29x46mm', 'Discharge Plug': ' 5.5mm Bullet', 'Capacity [mAh]': 5000.0, 'Weight [g]': 488.0, 'Price [USD]': 42.88, 'Constant Discharge [c]': 25, 'Peak Discharge [c]': 35}
# {'Name': 'Turnigy nano-tech 1000mAh 4S 45~90C Lipo Pack                                ', 'URL': 'https://hobbyking.com/en_us/turnigy-nano-tech-1000mah-4s-45-90c-lipo-pack.html', 'Voltage': ' 4S1P / 4 Cell / 14.8V', 'Balance Plug': ' JST-XH', 'Dimensions': ' 73x25x35mm', 'Discharge Plug': ' XT-60\xa0', 'Capacity [mAh]': 1000.0, 'Weight [g]': 124.0, 'Price [USD]': 16.44, 'Constant Discharge [c]': 45, 'Peak Discharge [c]': 90}
# {'Name': 'Turnigy nano-tech 1800mah 4S 25~50C Lipo Pack                                ', 'URL': 'https://hobbyking.com/en_us/turnigy-nano-tech-1800mah-4s-25-50c-lipo-pack.html', 'Voltage': ' 4S1P / 4 Cell / 14.8V', 'Balance Plug': ' JST-XH', 'Dimensions': ' 107x35x25mm', 'Discharge Plug': ' XT60 Connector', 'Capacity [mAh]': 1800.0, 'Weight [g]': 188.0, 'Price [USD]': 19.68, 'Constant Discharge [c]': 25, 'Peak Discharge [c]': 50}
# {'Name': 'Turnigy nano-tech 1800mah 4S 35~70C Lipo Pack                                ', 'URL': 'https://hobbyking.com/en_us/turnigy-nano-tech-1800mah-4s-35-70c-lipo-pack.html', 'Voltage': '\xa04S1P /\xa04 Cell / 14.8V', 'Balance Plug': '\xa0JST-XH', 'Dimensions': '\xa0103x35x29mm', 'Discharge Plug': '\xa0XT60 Connector', 'Capacity [mAh]': 1800.0, 'Weight [g]': 207.0, 'Price [USD]': 21.21, 'Constant Discharge [c]': 35, 'Peak Discharge [c]': 70}
# {'Name': 'Turnigy nano-tech 2200mah 4S 25~50C Lipo Pack                                ', 'URL': 'https://hobbyking.com/en_us/turnigy-nano-tech-2200mah-4s-25-50c-lipo-pack.html', 'Voltage': ' 4S1P /\xa04 Cell / 14.8V', 'Balance Plug': ' JST-XH', 'Dimensions': ' 100x35x30mm', 'Discharge Plug': ' XT60', 'Capacity [mAh]': 2200.0, 'Weight [g]': 218.0, 'Price [USD]': 21.99, 'Constant Discharge [c]': 25, 'Peak Discharge [c]': 50}
# {'Name': 'Turnigy nano-tech 2250mah 4S 65~130C Lipo Pack                                ', 'URL': 'https://hobbyking.com/en_us/turnigy-nano-tech-2250mah-4s-65-130c-lipo-pack.html', 'Voltage': ' 4S1P /\xa04 Cell / 14.8V', 'Balance Plug': ' JST-XH', 'Dimensions': ' 103 x 35 x 36mm', 'Discharge Plug': ' XT60', 'Capacity [mAh]': 2250.0, 'Weight [g]': 268.0, 'Price [USD]': 38.05, 'Constant Discharge [c]': 65, 'Peak Discharge [c]': 30}
# {'Name': 'Turnigy nano-tech 850mah 4S 25~50C Lipo Pack                                ', 'URL': 'https://hobbyking.com/en_us/turnigy-nano-tech-850mah-4s-25-50c-lipo-pack.html', 'Voltage': ' 4S1P / 4 Cell / 14.8V', 'Balance Plug': ' JST-XH', 'Dimensions': ' 56x30x31mm', 'Discharge Plug': ' XT-60', 'Capacity [mAh]': 850.0, 'Weight [g]': 94.0, 'Price [USD]': 10.99, 'Constant Discharge [c]': 25, 'Peak Discharge [c]': 50}
# {'Name': 'Turnigy nano-tech 850mAh 4S 45~90C Lipo Pack                                ', 'URL': 'https://hobbyking.com/en_us/turnigy-nano-tech-850mah-4s-45-90c-lipo-pack.html', 'Voltage': ' 4S1P /\xa04 Cell / 14.8V', 'Balance Plug': ' JST-XH', 'Dimensions': ' 56x31x33mm', 'Discharge Plug': '\xa0XT-60', 'Capacity [mAh]': 850.0, 'Weight [g]': 99.0, 'Price [USD]': 14.88, 'Constant Discharge [c]': 45, 'Peak Discharge [c]': 90}
# {'Name': 'ZIPPY Compact 2200mAh 4s 40c Lipo Pack                                ', 'URL': 'https://hobbyking.com/en_us/zippy-compact-2200mah-4s-40c-lipo-pack.html', 'Voltage': ' 4S1P / 4 Cell / 14.8V', 'Balance Plug': ' JST-XH', 'Dimensions': ' 105x34x34mm', 'Discharge Plug': ' XT60', 'Capacity [mAh]': 2200.0, 'Weight [g]': 248.0, 'Price [USD]': 24.36, 'Constant Discharge [c]': 40, 'Peak Discharge [c]': 50}
# {'Name': 'ZIPPY Compact 2200mAh 4s 60c Lipo Pack                                ', 'URL': 'https://hobbyking.com/en_us/zippy-compact-2200mah-4s-60c-lipo-pack.html', 'Voltage': ' 4S1P / 4 Cell / 14.8V', 'Balance Plug': ' JST-XH', 'Dimensions': ' 105x35x37mm', 'Discharge Plug': ' XT60', 'Capacity [mAh]': 2200.0, 'Weight [g]': 263.0, 'Price [USD]': 29.43, 'Constant Discharge [c]': 60, 'Peak Discharge [c]': 70}
# {'Name': 'ZIPPY Compact 2700mAh 4s 60c Lipo Pack                                ', 'URL': 'https://hobbyking.com/en_us/zippy-compact-2700mah-4s-60c-lipo-pack.html', 'Voltage': ' 4S1P / 4 Cell / 14.8V', 'Balance Plug': ' JST-XH', 'Dimensions': ' 139x45x27mm', 'Discharge Plug': ' XT60', 'Capacity [mAh]': 2700.0, 'Weight [g]': 317.0, 'Price [USD]': 34.26, 'Constant Discharge [c]': 60, 'Peak Discharge [c]': 70}
# {'Name': 'ZIPPY Compact 3300mAh 4s 60c Lipo Pack                                ', 'URL': 'https://hobbyking.com/en_us/zippy-compact-3300mah-4s-60c-lipo-pack.html', 'Voltage': ' 4S1P / 4 Cell / 14.8V', 'Balance Plug': ' JST-XH', 'Dimensions': ' 139x45x32mm', 'Discharge Plug': ' HXT4mm', 'Capacity [mAh]': 3300.0, 'Weight [g]': 382.0, 'Price [USD]': 42.41, 'Constant Discharge [c]': 60, 'Peak Discharge [c]': 70}
# {'Name': 'ZIPPY Compact 3700mAh 4s 60c Lipo Pack                                ', 'URL': 'https://hobbyking.com/en_us/zippy-compact-3700mah-4s-60c-lipo-pack.html', 'Voltage': ' 4S1P / 4 Cell / 14.8V', 'Balance Plug': ' JST-XH', 'Dimensions': ' 149x44x35mm', 'Discharge Plug': ' HXT4mm', 'Capacity [mAh]': 3700.0, 'Weight [g]': 442.0, 'Price [USD]': 46.44, 'Constant Discharge [c]': 60, 'Peak Discharge [c]': 70}
# {'Name': 'ZIPPY Compact 5800mAh 4s 40c Lipo Pack                                ', 'URL': 'https://hobbyking.com/en_us/zippy-compact-5800mah-4s-40c-lipo-pack.html', 'Voltage': ' 4S1P / 4 Cell / 14.8V', 'Balance Plug': ' JST-XH', 'Dimensions': ' 158x45x40mm', 'Discharge Plug': ' HXT4mm', 'Capacity [mAh]': 5800.0, 'Weight [g]': 562.0, 'Price [USD]': 56.96, 'Constant Discharge [c]': 40, 'Peak Discharge [c]': 50}
# {'Name': 'ZIPPY Compact 5800mAh 4s 60c Lipo Pack                                ', 'URL': 'https://hobbyking.com/en_us/zippy-compact-5800mah-4s-60c-lipo-pack.html', 'Voltage': ' 4S1P / 4 Cell / 14.8V', 'Balance Plug': ' JST-XH', 'Dimensions': ' 152x46x41mm', 'Discharge Plug': ' 5.5mm Bullet Connector', 'Capacity [mAh]': 5800.0, 'Weight [g]': 576.0, 'Price [USD]': 67.22, 'Constant Discharge [c]': 60, 'Peak Discharge [c]': 70}
# {'Name': 'ZIPPY Compact 6200mAh 4s 40c Lipo Pack                                ', 'URL': 'https://hobbyking.com/en_us/zippy-compact-6200mah-4s-40c-lipo-pack.html', 'Voltage': ' 4S1P / 4 Cell / 14.8V', 'Balance Plug': ' JST-XH', 'Dimensions': ' 158x46x41mm', 'Discharge Plug': ' HXT4mm', 'Capacity [mAh]': 6200.0, 'Weight [g]': 589.0, 'Price [USD]': 65.41, 'Constant Discharge [c]': 40, 'Peak Discharge [c]': 50}
# {'Name': 'Turnigy 3200mAh 4S 30C LiPoly Pack w/ EC3 (E-flite Compatible EFLB32004S30)                                 ', 'URL': 'https://hobbyking.com/en_us/turnigy-3200mah-4s-30c-lipoly-pack-w-ec3-e-flite-compatible-eflb32004s30.html', 'Dimensions': '\xa0139 x 45 x 29mm', 'Balance Plug': '\xa0JST-XH', 'Discharge Plug': '\xa0EC3', 'Configuration': ' 4S1P / 14.8v / 4Cell', 'Capacity [mAh]': 3200100.0, 'Weight [g]': 338.0, 'Price [USD]': 30.52, 'Constant Discharge [c]': 30, 'Peak Discharge [c]': 60}
# {'Name': 'Turnigy 2800mAh 4S 30C LiPoly Pack w/ EC3 (E-flite Compatible EFLB28004S30)                                 ', 'URL': 'https://hobbyking.com/en_us/turnigy-2800mah-4s-30c-lipoly-pack-w-ec3-e-flite-compatible-eflb28004s30.html', 'Dimensions': '\xa0115 x 36 x 40mm', 'Balance Plug': '\xa0JST-XH', 'Discharge Plug': '\xa0EC3', 'Configuration': ' 4S1P / 14.8v / 4Cell', 'Capacity [mAh]': 2800100.0, 'Weight [g]': 285.0, 'Price [USD]': 25.19, 'Constant Discharge [c]': 30, 'Peak Discharge [c]': 60}
# {'Name': 'Turnigy Graphene 1300mAh 4S 45C Lipo Pack w/ XT60                                ', 'URL': 'https://hobbyking.com/en_us/graphene-1300mah-4s-45c-w-xt60.html', 'Voltage': '\xa04S1P / 4 Cell / 14.8V', 'Balance Plug': '\xa0JST-XH', 'Dimensions': '\xa073x35x34mm', 'Discharge Plug': '\xa0XT-60', 'Capacity [mAh]': 1300.0, 'Weight [g]': 165.0, 'Price [USD]': 21.15, 'Constant Discharge [c]': 45, 'Peak Discharge [c]': 90}
# {'Name': 'Turnigy Graphene 1500mAh 4S 45C LiPo Pack w/ XT60                                ', 'URL': 'https://hobbyking.com/en_us/graphene-1500mah-4s-45c-w-xt60.html', 'Voltage': '\xa04S1P / 4 Cell / 14.8V', 'Balance Plug': '\xa0JST-XH', 'Dimensions': '\xa0107x35x28mm', 'Discharge Plug': '\xa0XT-60', 'Capacity [mAh]': 1500.0, 'Weight [g]': 201.0, 'Price [USD]': 24.45, 'Constant Discharge [c]': 45, 'Peak Discharge [c]': 90}
# {'Name': 'Turnigy Graphene 3000mAh 4S 45C Lipo Pack w/XT90                                ', 'URL': 'https://hobbyking.com/en_us/graphene-3000mah-4s-45c-w-xt90.html', 'Voltage': '\xa04S1P / 4 Cell / 14.8V', 'Balance Plug': '\xa0JST-XH', 'Dimensions': '\xa0136x45x30mm', 'Discharge Plug': '\xa0XT-90', 'Capacity [mAh]': 3000.0, 'Weight [g]': 376.0, 'Price [USD]': 52.75, 'Constant Discharge [c]': 45, 'Peak Discharge [c]': 90}
# {'Name': 'Turnigy Graphene 4000mAh 4S 45C Lipo Pack w/XT90                                ', 'URL': 'https://hobbyking.com/en_us/graphene-4000mah-4s-45c-w-xt90.html', 'Voltage': ' 4S1P / 4 Cell / 14.8V', 'Balance Plug': '\xa0JST-XH', 'Dimensions': '\xa0144x51x34mm', 'Discharge Plug': '\xa0XT-90', 'Capacity [mAh]': 4000.0, 'Weight [g]': 484.0, 'Price [USD]': 59.88, 'Constant Discharge [c]': 45, 'Peak Discharge [c]': 90}
# {'Name': 'Turnigy Graphene 5000mAh 4S 45C Lipo Pack w/XT90                                ', 'URL': 'https://hobbyking.com/en_us/graphene-5000mah-4s-45c-w-xt90.html', 'Voltage': '\xa04S1P / 4 Cell / 14.8V', 'Balance Plug': '\xa0JST-XH', 'Dimensions': '\xa0144x51x41mm', 'Discharge Plug': '\xa0XT-90', 'Capacity [mAh]': 5000.0, 'Weight [g]': 589.0, 'Price [USD]': 74.32, 'Constant Discharge [c]': 45, 'Peak Discharge [c]': 90}
# {'Name': 'ZIPPY Flightmax 5000mAh 4S1P 30C with XT90                                ', 'URL': 'https://hobbyking.com/en_us/zippy-flightmax-5000mah-4s1p-30c-with-xt90.html', 'Voltage': '\xa04S1P /\xa04 Cell / 14.8v', 'Balance Plug': '\xa0JST-XH', 'Dimensions': '\xa0143x51x34mm', 'Discharge Plug': ' XT90', 'Capacity [mAh]': 5000.0, 'Weight [g]': 490.0, 'Price [USD]': 38.84, 'Constant Discharge [c]': 30, 'Peak Discharge [c]': 60}
# {'Name': 'Turnigy Graphene 500mAh 4S 65C Lipo Pack (Short lead)                                ', 'URL': 'https://hobbyking.com/en_us/graphene-lipo-4s-65c-500mah-battery-short-lead.html', 'Voltage': '\xa04S1P / 4 Cell / 14.8V', 'Balance Plug': '\xa0JST-XH', 'Dimensions': '\xa056*31*29mm', 'Discharge Plug': '\xa0XT-60', 'Capacity [mAh]': 500.0, 'Weight [g]': 74.0, 'Price [USD]': 20.44, 'Constant Discharge [c]': 65, 'Peak Discharge [c]': 30}
# {'Name': 'Turnigy Heavy Duty 3300mAh 4S 60C Lipo Pack w/XT-90                                ', 'URL': 'https://hobbyking.com/en_us/turnigy-heavy-duty-3300mah-4s-60c-lipo-pack-w-xt90.html', 'Specs': ' ', 'Wire Gauge': ' 10AWG', 'Balance Plug': ' JST-XH', 'Discharge Plug': '\xa0XT90', 'Configuration': ' 4S1P / 14.8v / 4Cell', 'Dimensions': ' 136 x 45 x 32mm', 'Capacity [mAh]': 3300.0, 'Weight [g]': 385.0, 'Price [USD]': 40.35, 'Constant Discharge [c]': 60, 'Peak Discharge [c]': 20}
# {'Name': 'Turnigy Heavy Duty 4000mAh 4S 60C Lipo Pack w/XT-90                                ', 'URL': 'https://hobbyking.com/en_us/turnigy-battery-heavy-duty-4000mah-4s-60c-lipo-pack-xt-90.html', 'Specs': '\xa0', 'Wire Gauge': '\xa010AWG', 'Balance Plug': '\xa0JST-XH', 'Discharge Plug': ' XT-90', 'Configuration': '\xa04S1P / 14.8v / 4 Cell', 'Dimensions': '\xa0143 x 51 x 31mm', 'Capacity [mAh]': 4000.0, 'Weight [g]': 480.0, 'Price [USD]': 49.94, 'Constant Discharge [c]': 60, 'Peak Discharge [c]': 20}
# {'Name': 'Turnigy nano-tech 2700mah 4S 65~130C Lipo Pack w/XT-60                                ', 'URL': 'https://hobbyking.com/en_us/turnigy-battery-nano-tech-2700mah-4s-65-130c-lipo-pack-xt-60.html', 'Voltage': '\xa04S1P /\xa04 Cell / 14.8V', 'Balance Plug': '\xa0JST-XH', 'Dimensions': '\xa0134 x 44 x 27mm', 'Discharge Plug': '\xa0XT-60', 'Capacity [mAh]': 2700.0, 'Weight [g]': 332.0, 'Price [USD]': 45.1, 'Constant Discharge [c]': 65, 'Peak Discharge [c]': 30}
# {'Name': 'Turnigy nano-tech 3300mAh 4S 35~70C Lipo Pack w/XT-60                                ', 'URL': 'https://hobbyking.com/en_us/turnigy-nano-tech-3300mah-4s-35-70c-lipo-pack-xt-60.html', 'Voltage': ' 4S1P / 4S Cell / 14.8V', 'Balance Plug': ' JST-XH', 'Dimensions': ' 136x45x30mm', 'Discharge Plug': '\xa0XT60', 'Capacity [mAh]': 3300.0, 'Weight [g]': 360.0, 'Price [USD]': 47.4, 'Constant Discharge [c]': 35, 'Peak Discharge [c]': 70}
# {'Name': 'Turnigy nano-tech 3850mah 4S 65~130C Lipo Pack w/XT-90                                ', 'URL': 'https://hobbyking.com/en_us/turnigy-battery-nano-tech-3850mah-4s-65-130c-lipo-pack-xt-60.html', 'Voltage': '\xa04S1P /\xa04 Cell / 14.8V', 'Balance Plug': '\xa0JST-XH', 'Dimensions': '\xa0136 x 43 x 37mm', 'Discharge Plug': '\xa0XT-90', 'Capacity [mAh]': 3850.0, 'Weight [g]': 454.0, 'Price [USD]': 64.2, 'Constant Discharge [c]': 65, 'Peak Discharge [c]': 30}
# {'Name': 'Turnigy nano-tech 4500mah 4S 35~70C Lipo Pack w/XT-90                                ', 'URL': 'https://hobbyking.com/en_us/turnigy-battery-nano-tech-4500mah-4s-35-70c-lipo-pack-xt-60.html', 'Voltage': '\xa04S1P / 4S Cell / 14.8V', 'Balance Plug': '\xa0JST-XH', 'Dimensions': '\xa0153x49x30mm', 'Discharge Plug': '\xa0XT-90\xa0', 'Capacity [mAh]': 4500.0, 'Weight [g]': 485.0, 'Price [USD]': 53.06, 'Constant Discharge [c]': 35, 'Peak Discharge [c]': 70}
# {'Name': 'Turnigy nano-tech 5000mah 4S 25~50C Lipo Pack w/XT-90                                ', 'URL': 'https://hobbyking.com/en_us/turnigy-battery-nano-tech-5000mah-4s-25-50c-lipo-pack-xt-90.html', 'Voltage': '\xa04S1P /\xa04 Cell / 14.8V', 'Balance Plug': '\xa0JST-XH', 'Dimensions': '\xa0159x49x33mm', 'Discharge Plug': '\xa0XT-90', 'Capacity [mAh]': 5000.0, 'Weight [g]': 523.0, 'Price [USD]': 46.92, 'Constant Discharge [c]': 25, 'Peak Discharge [c]': 50}
# {'Name': 'Turnigy nano-tech 6000mAh 4S 25~50C Lipo Pack w/XT-90                                ', 'URL': 'https://hobbyking.com/en_us/turnigy-nano-tech-6000mah-4s-25-50c-lipo-pack-xt-90.html', 'Voltage': '\xa04S1P /\xa04 Cell / 14.8V', 'Balance Plug': '\xa0JST-XH', 'Dimensions': '\xa0175x49x38mm', 'Discharge Plug': '\xa0XT90', 'Capacity [mAh]': 6000.0, 'Weight [g]': 623.0, 'Price [USD]': 65.97, 'Constant Discharge [c]': 25, 'Peak Discharge [c]': 50}
# {'Name': 'Turnigy 3000mAh 4S 40C Lipo Pack w/XT-60                                ', 'URL': 'https://hobbyking.com/en_us/turnigy-battery-3000mah-4s-40c-lipo-pack-xt-60.html', 'Dimensions': '\xa0137 x\xa044 x 26mm', 'Balance Plug': '\xa0JST-XH\xa0', 'Discharge Plug': '\xa0XT-60', 'Configuration': '\xa04S1P / 14.8v / 4Cell', 'Capacity [mAh]': 3000.0, 'Weight [g]': 330.0, 'Price [USD]': 35.38, 'Constant Discharge [c]': 40, 'Peak Discharge [c]': 50}
# {'Name': 'Turnigy 3300mAh 4S 30C Lipo Pack XT-60                                ', 'URL': 'https://hobbyking.com/en_us/turnigy-battery-3300mah-4s-30c-lipo-pack-xt-60.html', 'Dimensions': '\xa0137 x\xa043 x 30mm', 'Balance Plug': '\xa0JST-XH', 'Discharge Plug': '\xa0XT-60', 'Configuration': '\xa04S1P / 14.8v / 4Cell', 'Capacity [mAh]': 3300.0, 'Weight [g]': 385.0, 'Price [USD]': 31.82, 'Constant Discharge [c]': 30, 'Peak Discharge [c]': 40}
# {'Name': 'Turnigy 4000mAh 4S 30C Lipo Pack w/XT-60                                ', 'URL': 'https://hobbyking.com/en_us/turnigy-battery-4000mah-4s-30c-lipo-pack-xt-60.html', 'Dimensions': '\xa0148 x\xa050 x 29mm', 'Balance Plug': '\xa0JST-XH\xa0', 'Discharge Plug': '\xa0XT-60', 'Configuration': '\xa04S1P / 14.8v / 4Cell', 'Capacity [mAh]': 4000.0, 'Weight [g]': 452.0, 'Price [USD]': 36.06, 'Constant Discharge [c]': 30, 'Peak Discharge [c]': 40}
# {'Name': 'Turnigy Graphene 1300mAh 4S 65C Square Lipo Battery Pack w/XT60                                ', 'URL': 'https://hobbyking.com/en_us/turnigy-graphene-1300mah-4s-65c-square-lipo-pack-xt60.html', 'Voltage': ' 4S1P / 4 Cell / 14.8V', 'Balance Plug': ' JST-XH', 'Dimensions': ' 51x50x39mm', 'Discharge Plug': ' XT-60', 'Capacity [mAh]': 1300.0, 'Weight [g]': 186.0, 'Price [USD]': 26.65, 'Constant Discharge [c]': 65, 'Peak Discharge [c]': 30}
# {'Name': 'Turnigy Graphene Panther 1400mAh 4S 75C Battery Pack w/XT60                                ', 'URL': 'https://hobbyking.com/en_us/turnigy-graphene-1400mah-4s-75c-lipo-pack-w-xt60.html', 'Cell Count': ' 4', 'Voltage': ' 14.8V', 'Pack Resistance': ' 17mΩ', 'Dimensions': ' 90x35x32mm', 'Balance Plug': ' JST-XH', 'Discharge Plug': ' XT60', 'Capacity [mAh]': 1400.0, 'Weight [g]': 196.0, 'Price [USD]': 27.86, 'Constant Discharge [c]': 75, 'Peak Discharge [c]': 150}
# {'Name': 'Turnigy Nano-Tech 2200mAh 4S 25C Lipo Pack w/XT60                                ', 'URL': 'https://hobbyking.com/en_us/turnigy-nano-tech-2200mah-4s-25c-lipo-pack-wxt60.html', 'Voltage': '\xa04S1P /\xa04 Cell / 14.8V', 'Balance Plug': '\xa0JST-XH', 'Dimensions': '\xa0103x35x30.8mm', 'Discharge Plug': '\xa0XT60', 'Capacity [mAh]': 2200.0, 'Weight [g]': 219.5, 'Price [USD]': 24.49, 'Constant Discharge [c]': 25, 'Peak Discharge [c]': 50}
# {'Name': 'ZIPPY Compact 4500mAh 4S 35C Lipo Pack                                ', 'URL': 'https://hobbyking.com/en_us/zippy-compact-4500mah-4s-35c-lipo-pack.html', 'Voltage': ' 4S1P /\xa04 Cell / 14.8V', 'Balance Plug': ' JST-XH', 'Dimensions': ' 159x46x38mm', 'Discharge Plug': ' 5.5mm Bullet', 'Capacity [mAh]': 4500.0, 'Weight [g]': 496.0, 'Price [USD]': 41.53, 'Constant Discharge [c]': 35, 'Peak Discharge [c]': 45}
# {'Name': 'Turnigy nano-tech 1300mAh 4S 45~90C Lipo Pack                                ', 'URL': 'https://hobbyking.com/en_us/turnigy-nano-tech-1300mah-4s-45-90c-lipo-pack.html', 'Voltage': ' 4S1P / 4 Cell / 14.8V', 'Balance Plug': ' JST-XH', 'Dimensions': ' 73x31x35mm', 'Discharge Plug': ' XT-60\xa0', 'Capacity [mAh]': 1300.0, 'Weight [g]': 155.0, 'Price [USD]': 20.72, 'Constant Discharge [c]': 45, 'Peak Discharge [c]': 90}
# {'Name': 'ZIPPY Compact 1800mAh 4s 40c Lipo Pack                                ', 'URL': 'https://hobbyking.com/en_us/zippy-compact-1800mah-4s-40c-lipo-pack.html', 'Voltage': ' 4S1P / 4 Cell / 14.8V', 'Balance Plug': ' JST-XH', 'Dimensions': ' 109x35x29mm', 'Discharge Plug': ' XT60', 'Capacity [mAh]': 1800.0, 'Weight [g]': 208.0, 'Price [USD]': 19.47, 'Constant Discharge [c]': 40, 'Peak Discharge [c]': 50}
# {'Name': 'Turnigy Graphene Professional 4000mAh 4S 15C LiPo Pack w/XT60                                ', 'URL': 'https://hobbyking.com/en_us/turnigy-graphene-4000mah-4s-15c-w-xt60.html', 'Voltage': ' 4S2P / 8 Cell / 14.8V', 'Balance Plug': '\xa0JST-XH', 'Dimensions': '\xa0108x35x54mm', 'Discharge Plug': '\xa0XT-60', 'Capacity [mAh]': 4000.0, 'Weight [g]': 396.0, 'Price [USD]': 40.42, 'Constant Discharge [c]': 15, 'Peak Discharge [c]': 30}
# {'Name': 'Turnigy 5000mAh 4S 40C Lipo Pack with XT90                                ', 'URL': 'https://hobbyking.com/en_us/turnigy-5000mah-4s-40c-lipo-pack-with-xt90.html', 'Dimensions': '\xa0143 x 51 x 38mm', 'Balance Plug': '\xa0JST-XH\xa0', 'Discharge Plug': ' XT90 ', 'Configuration': '\xa04S1P / 14.8v / 4Cell', 'Capacity [mAh]': 5000.0, 'Weight [g]': 550.0, 'Price [USD]': 50.61, 'Constant Discharge [c]': 40, 'Peak Discharge [c]': 80}
# {'Name': 'MultiStar Racer Series 1400mAh 4S 65C Multi-Rotor Lipo Pack (Gold Spec)                                ', 'URL': 'https://hobbyking.com/en_us/multistar-racer-series-1400mah-4s-65c-multi-rotor-lipo-pack-gold-spec.html', 'Dimensions': ' 90x35x30mm', 'Balance Plug': ' JST-XH', 'Discharge Plug': ' XT60', 'Configuration': ' 4S1P / 14.8V / 4Cell', 'Capacity [mAh]': 1400.0, 'Weight [g]': 181.0, 'Price [USD]': 27.1, 'Constant Discharge [c]': 65, 'Peak Discharge [c]': 130}
# {'Name': 'Turnigy 2200mAH 4S 20C Lipoly Pack w/ XT60 Connector                                ', 'URL': 'https://hobbyking.com/en_us/turnigy-2200mah-4s-20c-lipoly-pack-w-xt60-connector.html', 'Balance Plug': ' JST-XH ', 'Wire Gauge': ' 12AWG', 'Discharge Plug': ' XT60', 'Configuration': ' 4S1P / 14.8v / 4Cell', 'Dimensions': ' (L)105 x (W)35 x (H)31mm', 'Capacity [mAh]': 2200.0, 'Weight [g]': 224.0, 'Price [USD]': 19.94, 'Constant Discharge [c]': 20, 'Peak Discharge [c]': 40}
# {'Name': 'Turnigy 5000mAh 4S 25C Lipo Pack w/XT-90                                ', 'URL': 'https://hobbyking.com/en_us/turnigy-battery-5000mah-4s-25c-lipo-pack-xt-90.html', 'Dimensions': ' 147 x 49 x 33mm', 'Balance Plug': ' JST-XH', 'Discharge Plug': ' XT-90', 'Configuration': ' 4S1P / 14.8v / 4Cell', 'Capacity [mAh]': 5000.0, 'Weight [g]': 552.0, 'Price [USD]': 40.02, 'Constant Discharge [c]': 25, 'Peak Discharge [c]': 35}
# {'Name': 'ZIPPY Flightmax 3000mAh 4S1P 20C LiPo Pack w/XT60                                ', 'URL': 'https://hobbyking.com/en_us/zippy-flightmax-3000mah-4s1p-20c-lipo-pack-w-xt60.html', 'Voltage': ' 4S1P /\xa04 Cell / 14.8v', 'Balance Plug': ' JST-XH', 'Dimensions': ' 136x45x23mm', 'Discharge Plug': ' XT60', 'Capacity [mAh]': 3000.0, 'Weight [g]': 285.0, 'Price [USD]': 21.85, 'Constant Discharge [c]': 20, 'Peak Discharge [c]': 40}
# {'Name': 'Turnigy Graphene Panther 1600mAh 4S 75C Battery Pack (Removable Balance Lead)                                ', 'URL': 'https://hobbyking.com/en_us/graphene-1600mah-4s-75c-removable-balance-lead.html', 'Cell Count': ' 4', 'Voltage': ' 14.8V', 'Pack Resistance': ' 14mΩ', 'Dimensions': ' 94x35x36mm', 'Balance Plug': ' JST-XH-5P', 'Discharge Plug': ' XT60', 'Capacity [mAh]': 1600.0, 'Weight [g]': 214.0, 'Price [USD]': 34.98, 'Constant Discharge [c]': 75, 'Peak Discharge [c]': 150}
# {'Name': 'ZIPPY Compact 1300mAh 4s 40c Lipo Pack                                ', 'URL': 'https://hobbyking.com/en_us/zippy-compact-1300mah-4s-40c-lipo-pack.html', 'Voltage': ' 4S1P / 4 Cell / 14.8V', 'Balance Plug': ' JST-XH', 'Dimensions': ' 77x34x31mm', 'Discharge Plug': ' XT60', 'Capacity [mAh]': 1300.0, 'Weight [g]': 148.0, 'Price [USD]': 15.26, 'Constant Discharge [c]': 40, 'Peak Discharge [c]': 50}
# {'Name': 'Turnigy Graphene 1000mAh 4S 65C Lipo Pack w/ XT60                                ', 'URL': 'https://hobbyking.com/en_us/graphene-1000mah-4s-65c-w-xt60.html', 'Voltage': '\xa04S1P / 4 Cell / 14.8V', 'Balance Plug': '\xa0JST-XH', 'Dimensions': '\xa076x36x29mm', 'Discharge Plug': '\xa0XT-60', 'Capacity [mAh]': 1000.0, 'Weight [g]': 145.0, 'Price [USD]': 20.6, 'Constant Discharge [c]': 65, 'Peak Discharge [c]': 30}
# {'Name': 'Turnigy Graphene 750mah 4S 65C Lipo Pack (Short Lead)                                ', 'URL': 'https://hobbyking.com/en_us/turnigy-graphene-750mah-4s-65c-lipo-pack.html', 'Voltage': '\xa04S1P / 4 Cell / 14.8V', 'Balance Plug': '\xa0JST-XH', 'Dimensions': ' 74*36*23mm', 'Discharge Plug': '\xa0XT-60', 'Capacity [mAh]': 750.0, 'Weight [g]': 113.0, 'Price [USD]': 24.29, 'Constant Discharge [c]': 65, 'Peak Discharge [c]': 30}
# {'Name': 'Turnigy Bolt V2 1300mAh 4S 65~130C High Voltage Lipo Pack                                ', 'URL': 'https://hobbyking.com/en_us/turnigy-bolt-v2-lihv-1300mah-4s-65c.html', 'Voltage': ' 4S1P / 4 Cell / 15.2V', 'Balance Plug': '\xa0JST-XH', 'Wire Gauge': '\xa012AWG', 'Discharge Plug': '\xa0XT60U Bullet Connector', 'Dimensions': '\xa091\xa0x 29 x 35mm', 'Capacity [mAh]': 1300.0, 'Weight [g]': 172.0, 'Price [USD]': 28.32, 'Constant Discharge [c]': 65, 'Peak Discharge [c]': 30}
# {'Name': 'Turnigy Graphene 1300mAh 4S 65C Lipo Pack w/XT60 (Removable Balance Plug)                                ', 'URL': 'https://hobbyking.com/en_us/turnigy-graphene-1300mah-4s-65c-lipo-pack-w-xt60-removable-balance-plug.html', 'Voltage': ' 4S1P / 4 Cell / 14.8V', 'Balance Plug': ' JST-XH', 'Dimensions': ' 78x35x33mm', 'Discharge Plug': ' XT-60', 'Capacity [mAh]': 1300.0, 'Weight [g]': 166.0, 'Price [USD]': 28.68, 'Constant Discharge [c]': 65, 'Peak Discharge [c]': 30}
# {'Name': 'Turnigy High Capacity 4000mAh 4S 12C Multi-Rotor Lipo Pack w/XT60                                ', 'URL': 'https://hobbyking.com/en_us/turnigy-high-capacity-4000mah-4s-12c-multi-rotor-lipo-pack-w-xt60.html', 'Dimensions': '\xa0108 x 53 x 35mm', 'Balance Plug': ' JST-XH', 'Discharge Plug': ' XT60', 'Configuration': '\xa04S2P / 14.8V / 4Cell', 'Capacity [mAh]': 4000.0, 'Weight [g]': 382.0, 'Price [USD]': 32.5, 'Constant Discharge [c]': 12, 'Peak Discharge [c]': 24}
# {'Name': 'Turnigy High Capacity 5200mAh 4S 12C Multi-Rotor Lipo Pack w/XT60                                ', 'URL': 'https://hobbyking.com/en_us/turnigy-high-capacity-5200mah-4s-12c-multi-rotor-lipo-pack-w-xt60.html', 'Dimensions': '\xa0143 x 51 x 31mm', 'Balance Plug': ' JST-XH', 'Discharge Plug': ' XT60', 'Configuration': '\xa04S2P / 14.8V / 4Cell', 'Capacity [mAh]': 5200.0, 'Weight [g]': 450.0, 'Price [USD]': 53.96, 'Constant Discharge [c]': 12, 'Peak Discharge [c]': 24}
# {'Name': 'Turnigy High Capacity 6600mAh 4S 12C Multi-Rotor Lipo Pack w/XT60                                ', 'URL': 'https://hobbyking.com/en_us/turnigy-high-capacity-battery-6600mah-64s-12c-drone-lipo-pack-xt60.html', 'Cell Count': ' 4 / 14.8V', 'Dimensions': '\xa0144 x 42 x 51mm', 'Balance Plug': '\xa0JST-XH', 'Discharge Plug': '\xa0XT60', 'Capacity [mAh]': 6600.0, 'Weight [g]': 598.0, 'Price [USD]': 47.6, 'Constant Discharge [c]': 12, 'Peak Discharge [c]': 24}
# {'Name': 'Turnigy Graphene Panther 5000mAh 4S 75C Battery Pack w/XT90                                ', 'URL': 'https://hobbyking.com/en_us/turnigy-graphene-5000mah-4s-75c-lipo-pack-w-xt90.html', 'Cell Count': ' 4', 'Voltage': ' 14.8V', 'Pack Resistance': ' 11mΩ', 'Dimensions': ' 145x51x42mm', 'Balance Plug': ' JST-XH', 'Discharge Plug': ' XT90', 'Capacity [mAh]': 5000.0, 'Weight [g]': 630.0, 'Price [USD]': 81.59, 'Constant Discharge [c]': 75, 'Peak Discharge [c]': 150}
# {'Name': 'Turnigy Nano-Tech Plus 1800mAh 4S 70C Lipo Pack w/XT60 (Removable Balance Plug)                                ', 'URL': 'https://hobbyking.com/en_us/turnigy-nano-tech-1800mah-4s-70c-lipo-pack-xt60-hr-tech.html', 'Voltage': '\xa04S1P /\xa04 Cell / 14.8V', 'Balance Plug': '\xa0JST-XH', 'Dimensions': '\xa0112x35x29.8mm', 'Discharge Plug': '\xa0XT60', 'Capacity [mAh]': 1800.0, 'Weight [g]': 205.0, 'Price [USD]': 27.62, 'Constant Discharge [c]': 70, 'Peak Discharge [c]': 40}
# {'Name': 'Turnigy Nano-Tech Plus 2200mAh 4S 70C Lipo Pack w/XT90                                ', 'URL': 'https://hobbyking.com/en_us/turnigy-nano-tech-2200mah-4s-70c-lipo-pack-w-xt90-hr-tech.html', 'Voltage': '\xa04S1P /\xa04 Cell / 14.8V', 'Balance Plug': '\xa0JST-XH', 'Dimensions': '\xa0104x35x37.2mm', 'Discharge Plug': '\xa0XT90', 'Capacity [mAh]': 2200.0, 'Weight [g]': 265.26, 'Price [USD]': 33.06, 'Constant Discharge [c]': 70, 'Peak Discharge [c]': 40}
# {'Name': 'Turnigy Nano-Tech 3000mAh 4S 30C Lipo Pack w/XT60                                ', 'URL': 'https://hobbyking.com/en_us/turnigy-nano-tech-3000mah-4s-30c-lipo-pack-wxt60.html', 'Voltage': '\xa04S1P /\xa04 Cell / 14.8V', 'Balance Plug': '\xa0JST-XH', 'Dimensions': '\xa0135x44x22.2mm', 'Discharge Plug': '\xa0XT60', 'Capacity [mAh]': 3000.0, 'Weight [g]': 277.29, 'Price [USD]': 33.29, 'Constant Discharge [c]': 30, 'Peak Discharge [c]': 60}
# {'Name': 'Turnigy Nano-Tech 4000mAh 4S 30C Lipo Pack w/XT60                                ', 'URL': 'https://hobbyking.com/en_us/turnigy-nano-tech-4000mah-4s-30c-lipo-pack-wxt60.html', 'Voltage': '\xa04S1P /\xa04 Cell / 14.8V', 'Balance Plug': '\xa0JST-XH', 'Dimensions': '\xa0154x49x25.6mm', 'Discharge Plug': '\xa0XT60', 'Capacity [mAh]': 4000.0, 'Weight [g]': 392.24, 'Price [USD]': 41.28, 'Constant Discharge [c]': 30, 'Peak Discharge [c]': 60}
# {'Name': 'Turnigy Graphene 500mAh 4S 65C Lipo w/XT30                                ', 'URL': 'https://hobbyking.com/en_us/turnigy-graphene-500mah-4s-65c-lipo-pack-w-xt30.html', 'Cell Count': ' 4', 'Voltage': ' 14.8V', 'Balance Plug': '\xa0JST-XH', 'Dimensions': ' 56x31x29mm', 'Discharge Plug': '\xa0XT30', 'Capacity [mAh]': 500.0, 'Weight [g]': 74.0, 'Price [USD]': 20.03, 'Constant Discharge [c]': 65, 'Peak Discharge [c]': 130}
# {'Name': 'Turnigy Graphene Panther 1300mAh 4S 75C Battery Pack                                ', 'URL': 'https://hobbyking.com/en_us/graphene-1300mah-4s-75c.html', 'Cell Count': ' 4', 'Voltage': ' 14.8V', 'Pack Resistance': ' 12mΩ', 'Dimensions': ' 75x35x36mm', 'Balance Plug': ' JST-XH-5P', 'Discharge Plug': ' XT60', 'Capacity [mAh]': 1300.0, 'Weight [g]': 173.0, 'Price [USD]': 26.89, 'Constant Discharge [c]': 75, 'Peak Discharge [c]': 150}
# {'Name': 'Turnigy 1600mAh 4S 30C Lipo Pack                                ', 'URL': 'https://hobbyking.com/en_us/turnigy-1600mah-4s-30c-lipo-pack.html', 'Dimensions': '\xa090 x\xa035 x 25mm', 'Balance Plug': ' JST-XH ', 'Discharge Plug': '\xa0XT60 \xa0', 'Configuration': ' 4S1P / 14.8v / 4Cell', 'Capacity [mAh]': 1600.0, 'Weight [g]': 177.0, 'Price [USD]': 19.77, 'Constant Discharge [c]': 30, 'Peak Discharge [c]': 40}
# {'Name': 'Turnigy 1800mAh 4S 30C Lipo Pack                                ', 'URL': 'https://hobbyking.com/en_us/turnigy-1800mah-4s-30c-lipo-pack.html', 'Dimensions': '\xa0105 x\xa035 x 26mm', 'Balance Plug': ' JST-XH', 'Discharge Plug': ' XT60\xa0', 'Configuration': ' 4S1P / 14.8v / 4Cell', 'Capacity [mAh]': 1800.0, 'Weight [g]': 185.0, 'Price [USD]': 24.77, 'Constant Discharge [c]': 30, 'Peak Discharge [c]': 40}

# %%
df = pd.DataFrame(products)
df['Capacity [Ah]'] = df['Capacity [mAh]'] / 1000
df['Energy [Wh]'] = 14.8 * df['Capacity [Ah]']
df['Energy Density [Wh/g]'] = df['Energy [Wh]'] / df['Weight [g]']
df['Constant Discharge [A]'] = df['Constant Discharge [c]'] * df['Capacity [Ah]']
df['Energy Value [Wh/$]'] = df['Energy [Wh]'] / df['Price [USD]']

# %%
filtered = df[(df['Weight [g]'] < 210) & 
              (df['Energy [Wh]']>18) &
              (df['Constant Discharge [A]'] > ((12*4)+1))]

# %%
filtered.sort_values('Energy Density [Wh/g]', ascending=False).head(5)
# Out:
#    Balance Plug  Capacity  Capacity [mAh] Cell Count          Configuration  \
# 1        JST-XH     850.0          8500.0          4                    NaN
# 99       JST-XH       NaN          1800.0        NaN   4S1P / 14.8v / 4Cell
# 4        JST-XH       NaN          1400.0        NaN   4S1P / 14.8v / 4Cell
# 30       JST-XH       NaN          1600.0        NaN                    NaN
# 83       JST-XH       NaN          1300.0        NaN                    NaN
#
#     Constant Discharge [c]           Dimensions Discharge Plug  \
# 1                       75           56x31x38mm           XT60
# 99                      30      105 x 35 x 26mm          XT60
# 4                       40   87.5 x 33.5 x 27mm           XT60
# 30                      35          106x34x23mm           XT60
# 83                      40           77x34x31mm           XT60
#
#    Max Charge Rate                                               Name  ...  \
# 1              NaN  Turnigy Graphene Panther 850mAh 4S 75C Battery...  ...
# 99             NaN  Turnigy 1800mAh 4S 30C Lipo Pack              ...  ...
# 4              NaN  Turnigy 1400mAh 4S 40C Lipo Pack w/XT60       ...  ...
# 30             NaN  ZIPPY Compact 1600mAh 4S 35C Lipo Pack        ...  ...
# 83             NaN  ZIPPY Compact 1300mAh 4s 40c Lipo Pack        ...  ...
#
#    Specs                                                URL  \
# 1    NaN  https://hobbyking.com/en_us/turnigy-graphene-8...
# 99   NaN  https://hobbyking.com/en_us/turnigy-1800mah-4s...
# 4    NaN  https://hobbyking.com/en_us/turnigy-1400mah-4s...
# 30   NaN  https://hobbyking.com/en_us/zippy-compact-1600...
# 83   NaN  https://hobbyking.com/en_us/zippy-compact-1300...
#
#                    Voltage Weight [g] Wire Gauge Capacity [Ah]  Energy [Wh]  \
# 1                    14.8V      120.0        NaN           8.5       125.80
# 99                     NaN      185.0        NaN           1.8        26.64
# 4                      NaN      153.0        NaN           1.4        20.72
# 30   4S1P / 4 Cell / 14.8V      178.0        NaN           1.6        23.68
# 83   4S1P / 4 Cell / 14.8V      148.0        NaN           1.3        19.24
#
#    Energy Density [Wh/g]  Constant Discharge [A]  Energy Value [Wh/$]
# 1               1.048333                   637.5             6.698616
# 99              0.144000                    54.0             1.075495
# 4               0.135425                    56.0             1.481058
# 30              0.133034                    56.0             1.221248
# 83              0.130000                    52.0             1.260813
#
# [5 rows x 23 columns]

# %%
filtered.sort_values('Energy Value [Wh/$]', ascending=False).head(5)
# Out:
#     Configuration Balance Plug  Capacity Cell Count          Configuration  \
# 4             NaN       JST-XH    1400.0        NaN   4S1P / 14.8v / 4Cell
# 3             NaN       JST-XH    1400.0        NaN   4S1P / 14.8v / 4Cell
# 75            NaN       JST-XH    1800.0        NaN                    NaN
# 83            NaN       JST-XH    1300.0        NaN                    NaN
# 37            NaN       JST-XH    1800.0        NaN                    NaN
#
#     Constant Discharge           Dimensions   Discharge Plug Max Charge Rate  \
# 4                   40   87.5 x 33.5 x 27mm             XT60             NaN
# 3                   65      91.5 x 35 x31mm             XT60             NaN
# 75                  40          109x35x29mm             XT60             NaN
# 83                  40           77x34x31mm             XT60             NaN
# 37                  35          103x35x29mm   XT60 Connector             NaN
#
#                                                  Name  ... Specs  \
# 4   Turnigy 1400mAh 4S 40C Lipo Pack w/XT60       ...  ...   NaN
# 3   Turnigy 1400mAh 4S 65C Lipo Pack w/XT60       ...  ...   NaN
# 75  ZIPPY Compact 1800mAh 4s 40c Lipo Pack        ...  ...   NaN
# 83  ZIPPY Compact 1300mAh 4s 40c Lipo Pack        ...  ...   NaN
# 37  Turnigy nano-tech 1800mah 4S 35~70C Lipo Pack ...  ...   NaN
#
#                                                   URL                 Voltage  \
# 4   https://hobbyking.com/en_us/turnigy-1400mah-4s...                     NaN
# 3   https://hobbyking.com/en_us/turnigy-1400mah-4s...                     NaN
# 75  https://hobbyking.com/en_us/zippy-compact-1800...   4S1P / 4 Cell / 14.8V
# 83  https://hobbyking.com/en_us/zippy-compact-1300...   4S1P / 4 Cell / 14.8V
# 37  https://hobbyking.com/en_us/turnigy-nano-tech-...   4S1P / 4 Cell / 14.8V
#
#    Weight Wire Gauge Capacity [Ah]  Energy [Wh] Energy Density [Wh/g]  \
# 4   153.0        NaN           1.4        20.72              0.135425
# 3   179.0        NaN           1.4        20.72              0.115754
# 75  208.0        NaN           1.8        26.64              0.128077
# 83  148.0        NaN           1.3        19.24              0.130000
# 37  207.0        NaN           1.8        26.64              0.128696
#
#     Constant Discharge [A]  Energy Value [Wh/$]
# 4                     56.0             1.481058
# 3                     91.0             1.382255
# 75                    72.0             1.368259
# 83                    52.0             1.260813
# 37                    63.0             1.256011
#
# [5 rows x 23 columns]

# %%
df.iloc[30]['URL']
# Out:
# 'https://hobbyking.com/en_us/zippy-compact-1600mah-4s-35c-lipo-pack.html'

# %%
df.columns
# Out:
# Index(['Balance Plug', 'Capacity', 'Capacity [mAh]', 'Cell Count',
#        'Configuration', 'Constant Discharge [c]', 'Dimensions',
#        'Discharge Plug', 'Max Charge Rate', 'Name', 'Pack Resistance',
#        'Peak Discharge [c]', 'Price [USD]', 'Specs', 'URL', 'Voltage',
#        'Weight [g]', 'Wire Gauge', 'Capacity [Ah]', 'Energy [Wh]',
#        'Energy Density [Wh/g]', 'Constant Discharge [A]',
#        'Energy Value [Wh/$]'],
#       dtype='object')

# %%
df.to_csv('batteries.csv')
